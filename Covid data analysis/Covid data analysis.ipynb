# %% [markdown]
# <div style="background-color: #000080; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Lab COVID-19 Global Statistics - Exploratory Data Analysis
# </h1>
# </div>

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import plotly.express as px
from scipy import stats
from scipy.stats import zscore
import seaborn as sns
from scipy.stats.mstats import winsorize 
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.io as pio

# %%
#Loading the dataset into a dataframe
df_raw=pd.read_csv('COVID-19 Global Statistics Dataset.csv')
df_raw.head()
# Out:
#    Country  Total Cases New Cases Total Deaths  New Deaths Total Recovered  \
# 0      USA  111,367,209       NaN    1,199,031         NaN     109,053,249
# 1    India   45,028,429       161      533,475       2.000             NaN
# 2   France   40,138,560       NaN      167,642         NaN      39,970,918
# 3  Germany   38,819,284       574      182,439      28.000      38,240,600
# 4   Brazil   38,407,327       NaN      709,765         NaN      36,249,161
#
#   New Recovered Active Cases Serious, Critical Tot Cases/1M pop Deaths/1M pop  \
# 0           NaN    1,114,929             1,771          332,633         3,581
# 1           NaN          NaN               NaN           32,012           379
# 2           NaN            0               NaN          612,013         2,556
# 3           NaN      396,245               NaN          462,776         2,175
# 4           NaN    1,448,401               NaN          178,345         3,296
#
#      Total Tests Tests/1M pop     Population
# 0  1,186,742,917    3,544,577    334,805,269
# 1    935,879,495      665,334  1,406,631,776
# 2    271,490,188    4,139,547     65,584,518
# 3    122,332,384    1,458,359     83,883,596
# 4     63,776,166      296,146    215,353,593

# %%
#diplaying last 10 elements of the dataframe
df_raw.tail(10)
# Out:
#         Country  Total Cases New Cases Total Deaths  New Deaths  \
# 229  MS Zaandam            9       NaN            2         NaN
# 230       China      503,302       NaN        5,272         NaN
# 231      Total:  131,413,625       NaN    1,674,775         NaN
# 232      Total:  221,452,228       161    1,553,005       2.000
# 233      Total:  253,186,231       940    2,100,109      35.000
# 234      Total:   69,791,773       NaN    1,365,551         NaN
# 235      Total:   14,826,780     1,345       32,665         NaN
# 236      Total:   12,859,770       NaN      258,884         NaN
# 237      Total:          721       NaN           15         NaN
# 238      Total:  703,531,128     2,446    6,985,004      37.000
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 229               7           NaN            0               NaN
# 230         379,053           NaN      118,977               NaN
# 231     126,866,566           NaN    2,872,284             6,926
# 232     205,616,782           583   14,282,441            14,733
# 233     248,509,042         2,477    2,577,080             4,521
# 234      66,648,277           NaN    1,777,945             8,953
# 235      14,572,565           NaN      221,550                33
# 236      12,089,899           NaN      510,987               529
# 237             706           NaN            0                 0
# 238     674,303,837         5,178   22,242,287            35,695
#
#     Tot Cases/1M pop Deaths/1M pop  Total Tests Tests/1M pop     Population
# 229              NaN           NaN          NaN          NaN            NaN
# 230              347             4  160,000,000      110,461  1,448,471,400
# 231              NaN           NaN          NaN          NaN            NaN
# 232              NaN           NaN          NaN          NaN            NaN
# 233              NaN           NaN          NaN          NaN            NaN
# 234              NaN           NaN          NaN          NaN            NaN
# 235              NaN           NaN          NaN          NaN            NaN
# 236              NaN           NaN          NaN          NaN            NaN
# 237              NaN           NaN          NaN          NaN            NaN
# 238        90,256.50         896.1          NaN          NaN            NaN

# %%
#displaying sample 10 rows from the dataset
df_raw.sample(10)
# Out:
#          Country Total Cases New Cases Total Deaths  New Deaths  \
# 196        Yemen      11,945       NaN        2,159         NaN
# 29       Belgium   4,858,488       NaN       34,376         NaN
# 47    Bangladesh   2,047,373       NaN       29,482         NaN
# 143   Cabo Verde      64,477       NaN          417         NaN
# 130          DRC      99,338       NaN        1,468         NaN
# 190     Djibouti      15,690       NaN          189         NaN
# 181  South Sudan      18,819       NaN          147         NaN
# 28        Canada   4,929,750       NaN       58,348         NaN
# 220       Tuvalu       2,943       NaN            1         NaN
# 22        Greece   6,101,379       NaN       37,869         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 196           9,124           NaN          662               NaN
# 29        4,820,246           168        3,866               NaN
# 47              NaN           NaN          NaN               NaN
# 143          63,755           NaN          305                23
# 130          84,489           NaN       13,381               NaN
# 190          15,427           NaN           74               NaN
# 181          18,115           NaN          557                 1
# 28        4,852,719         2,116       18,683                99
# 220             NaN           NaN          NaN               NaN
# 22              NaN           NaN          NaN               NaN
#
#     Tot Cases/1M pop Deaths/1M pop  Total Tests Tests/1M pop   Population
# 196              383            69      329,592       10,579   31,154,867
# 29           416,384         2,946   37,454,182    3,209,915   11,668,278
# 47            12,195           176   15,254,399       90,862  167,885,689
# 143          113,580           735      401,622      707,482      567,678
# 130            1,043            15      846,704        8,890   95,240,792
# 190           15,441           186      305,941      301,094    1,016,097
# 181            1,620            13      410,280       35,313   11,618,511
# 28           128,418         1,520   66,572,774    1,734,189   38,388,419
# 220          243,909            83          NaN          NaN       12,066
# 22           591,412         3,671  102,228,365    9,909,078   10,316,637

# %%
#shape of the dataset
print(f'The dataset contains {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# The dataset contains 231 rows and 14 columns

# %%
#creating a new dataframe named df that contains data regarding only countrues (excluding 'Total' columns) from the df_raw dataframe
df=df_raw.loc[:230]
df
# Out:
#             Country  Total Cases New Cases Total Deaths  New Deaths  \
# 0               USA  111,367,209       NaN    1,199,031         NaN
# 1             India   45,028,429       161      533,475       2.000
# 2            France   40,138,560       NaN      167,642         NaN
# 3           Germany   38,819,284       574      182,439      28.000
# 4            Brazil   38,407,327       NaN      709,765         NaN
# ..              ...          ...       ...          ...         ...
# 226         Tokelau           80       NaN          NaN         NaN
# 227    Vatican City           29       NaN          NaN         NaN
# 228  Western Sahara           10       NaN            1         NaN
# 229      MS Zaandam            9       NaN            2         NaN
# 230           China      503,302       NaN        5,272         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0       109,053,249           NaN    1,114,929             1,771
# 1               NaN           NaN          NaN               NaN
# 2        39,970,918           NaN            0               NaN
# 3        38,240,600           NaN      396,245               NaN
# 4        36,249,161           NaN    1,448,401               NaN
# ..              ...           ...          ...               ...
# 226             NaN           NaN           80               NaN
# 227              29           NaN            0               NaN
# 228               9           NaN            0               NaN
# 229               7           NaN            0               NaN
# 230         379,053           NaN      118,977               NaN
#
#     Tot Cases/1M pop Deaths/1M pop    Total Tests Tests/1M pop     Population
# 0            332,633         3,581  1,186,742,917    3,544,577    334,805,269
# 1             32,012           379    935,879,495      665,334  1,406,631,776
# 2            612,013         2,556    271,490,188    4,139,547     65,584,518
# 3            462,776         2,175    122,332,384    1,458,359     83,883,596
# 4            178,345         3,296     63,776,166      296,146    215,353,593
# ..               ...           ...            ...          ...            ...
# 226           58,055           NaN            NaN          NaN          1,378
# 227           36,295           NaN            NaN          NaN            799
# 228               16             2            NaN          NaN        626,161
# 229              NaN           NaN            NaN          NaN            NaN
# 230              347             4    160,000,000      110,461  1,448,471,400
#
# [231 rows x 14 columns]

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# Country                0
# Total Cases            0
# New Cases            223
# Total Deaths           5
# New Deaths           227
# Total Recovered       49
# New Recovered        217
# Active Cases          48
# Serious, Critical    179
# Tot Cases/1M pop       2
# Deaths/1M pop          7
# Total Tests           18
# Tests/1M pop          18
# Population             2
# dtype: int64

# %%
#bar plot of null values in each column
df.isna().sum().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#checking for duplicate records
print(f'Total duplicate values: {df.duplicated().sum()}')
# Out:
# Total duplicate values: 0

# %%
#datatypes of each column
dataTypes = df.dtypes
dataTypes
# Out:
# Country               object
# Total Cases           object
# New Cases             object
# Total Deaths          object
# New Deaths           float64
# Total Recovered       object
# New Recovered         object
# Active Cases          object
# Serious, Critical     object
# Tot Cases/1M pop      object
# Deaths/1M pop         object
# Total Tests           object
# Tests/1M pop          object
# Population            object
# dtype: object

# %%
#changing the data type of columns from object to float
df['Total Cases'] = df['Total Cases'].str.replace(',', '')
df['Total Cases'] = df['Total Cases'].apply(lambda x: float(x))

df['New Cases'] = df['New Cases'].str.replace(',', '')
df['New Cases'] = df['New Cases'].apply(lambda x: float(x))

df['Total Recovered'] = df['Total Recovered'].str.replace(',', '')
df['Total Recovered'] = df['Total Recovered'].apply(lambda x: float(x))

df['Total Deaths'] = df['Total Deaths'].str.replace(',', '')
df['Total Deaths'] = df['Total Deaths'].apply(lambda x: float(x))

df['New Recovered'] = df['New Recovered'].str.replace(',', '')
df['New Recovered'] = df['New Recovered'].apply(lambda x: float(x))

df['Active Cases'] = df['Active Cases'].str.replace(',', '')
df['Active Cases'] = df['Active Cases'].apply(lambda x: float(x))

df['Serious, Critical'] = df['Serious, Critical'].str.replace(',', '')
df['Serious, Critical'] = df['Serious, Critical'].apply(lambda x: float(x))

df['Tot Cases/1M pop'] = df['Tot Cases/1M pop'].str.replace(',', '')
df['Tot Cases/1M pop'] = df['Tot Cases/1M pop'].apply(lambda x: float(x))

df['Deaths/1M pop'] = df['Deaths/1M pop'].str.replace(',', '')
df['Deaths/1M pop'] = df['Deaths/1M pop'].apply(lambda x: float(x))

df['Total Tests'] = df['Total Tests'].str.replace(',', '')
df['Total Tests'] = df['Total Tests'].apply(lambda x: float(x))

df['Tests/1M pop'] = df['Tests/1M pop'].str.replace(',', '')
df['Tests/1M pop'] = df['Tests/1M pop'].apply(lambda x: float(x))

df['Population'] = df['Population'].str.replace(',', '')
df['Population'] = df['Population'].apply(lambda x: float(x))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:33: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\2959429591.py:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#filling null values with 0 to help visualization and calculations
df.fillna({'New Cases':0,'New Deaths':0,'New Recovered':0,'Serious, Critical':0,'Total Deaths':0,'Total Recovered':0,'Active Cases':0,'Tot Cases/1M pop':0,'Deaths/1M pop':0,'Total Tests':0,'Tests/1M pop':0,'Population':0},inplace=True)
display(df['New Cases'].isnull().sum())
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\4143502899.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0

# %%
#checking data types after conversion
dataTypes = df.dtypes
dataTypes
# Out:
# Country               object
# Total Cases          float64
# New Cases            float64
# Total Deaths         float64
# New Deaths           float64
# Total Recovered      float64
# New Recovered        float64
# Active Cases         float64
# Serious, Critical    float64
# Tot Cases/1M pop     float64
# Deaths/1M pop        float64
# Total Tests          float64
# Tests/1M pop         float64
# Population           float64
# dtype: object

# %%
#descriptive statistics of df
df.describe(include='all')
# Out:
#        Country   Total Cases  New Cases  Total Deaths  New Deaths  \
# count      231       231.000    231.000       231.000     231.000
# unique     231           NaN        NaN           NaN         NaN
# top        USA           NaN        NaN           NaN         NaN
# freq         1           NaN        NaN           NaN         NaN
# mean       NaN   3045589.299     10.589     30238.113       0.160
# std        NaN   9992409.504     97.607    108207.338       1.887
# min        NaN         9.000      0.000         0.000       0.000
# 25%        NaN     26069.500      0.000       185.500       0.000
# 50%        NaN    206897.000      0.000      1971.000       0.000
# 75%        NaN   1347861.500      0.000     14287.000       0.000
# max        NaN 111367209.000   1345.000   1199031.000      28.000
#
#         Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# count           231.000        231.000       231.000            231.000
# unique              NaN            NaN           NaN                NaN
# top                 NaN            NaN           NaN                NaN
# freq                NaN            NaN           NaN                NaN
# mean        2370656.905         21.745     26393.537             16.355
# std         9135558.727        160.860    141214.482            121.532
# min               0.000          0.000        -1.000              0.000
# 25%            1767.500          0.000         0.000              0.000
# 50%           54578.000          0.000       141.000              0.000
# 75%         1020058.000          0.000      2729.000              0.000
# max       109053249.000       2116.000   1448401.000           1771.000
#
#         Tot Cases/1M pop  Deaths/1M pop    Total Tests  Tests/1M pop  \
# count            231.000        231.000        231.000       231.000
# unique               NaN            NaN            NaN           NaN
# top                  NaN            NaN            NaN           NaN
# freq                 NaN            NaN            NaN           NaN
# mean          201035.143       1237.377   30411252.463   1987569.550
# std           206006.008       1307.720  115419167.317   3549645.344
# min                0.000          0.000          0.000         0.000
# 25%            17655.500        133.500     226058.500     84659.000
# 50%           128418.000        783.000    1690934.000    717380.000
# 75%           327944.500       2038.500   11639857.000   2126400.500
# max           769596.000       6595.000 1186742917.000  23302116.000
#
#            Population
# count         231.000
# unique            NaN
# top               NaN
# freq              NaN
# mean     34393658.576
# std     138070938.681
# min             0.000
# 25%        428111.500
# 50%       5554960.000
# 75%      21839340.000
# max    1448471400.000

# %% [markdown]
# ## Overall situation analysis

# %%
#covid incubation period

def plot_cal(title, start, end):
    '''Plot incubation period'''
    inc_day = []
    for i in range(1, 29):
        if(i>=start and i<=end):
            inc_day.append(1)
        else:
            inc_day.append(0)
            
    inc_day = np.array(inc_day)
    inc_day = inc_day.reshape(4, 7)
    
    fig, ax = plt.subplots(figsize=(6, 3))
    ax=sns.heatmap(inc_day, linewidths=2, square=True, 
                   xticklabels='', yticklabels='', ax=ax,
                   cbar=False, cmap=['whitesmoke','red'])
    ax.set_title(title, fontdict={'fontsize':16}, loc='left', pad=15)
    
    plt.show()
    
plot_cal('Incubation period of Covid (1 to 6 days)', 1, 6)

# %%
#Bar chart showing the top 10 Countries with highest number of Total Confirmed Cases
top_cases_df= df.sort_values('Total Cases',ascending = False).head(10)
top_cases_df = top_cases_df.drop(top_cases_df[top_cases_df['Country'] == 'Total:'].index)
plt.figure(figsize=(12,12))
ax=sns.barplot(y = 'Country',
            x = 'Total Cases',
            data = top_cases_df);

plt.title('Top 10 Countries with highest number of Total Confirmed Cases')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with highest number of Total Confirmed Cases')

# %%
#filling in the null values of total recovered column
#plotting pie chart of total recovered vs total deaths
df['Total Recovered'] = df['Total Recovered'].fillna(df['Total Cases'] - df['Total Deaths'])

total_recovered = df['Total Recovered'].sum()
total_deaths = df['Total Deaths'].sum()

sizes = [total_recovered, total_deaths]
labels = ['Total Recovered', 'Total Deaths']

plt.figure(figsize=(5,5))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.axis('equal')
plt.title('Distribution of Total Recovered and Total Deaths')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2704\1388977670.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#bar plot of total recovered vs total deaths

plt.figure(figsize=(12, 6))

x=np.arange(10)
width = 0.2
  
# plot data in grouped manner of bar type 
plt.bar(x-0.2, df[:10]['Total Recovered'], width, color='red') 
plt.bar(x, df[:10]['Total Deaths'], width, color='green') 
plt.xticks(x, df[:10]['Country']) 
plt.xlabel("Countries") 
plt.ylabel("Numbers") 
plt.legend(["Total Recovered", "Total Deaths"]) 
plt.show()

# %%
#scatter plot of total cases vs total deaths

# Sample data for demonstration
total_deaths = df['Total Deaths'].tolist()  # List of total deaths for each country
total_cases = df['Total Cases'].tolist()  # List of total cases for each country
country_names = df['Country'].tolist() # List of country names

# Plotting scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(total_cases, total_deaths, color='skyblue', alpha=0.7)

# Adding country names to the plot
for i, country in enumerate(country_names):
    plt.text(total_cases[i], total_deaths[i], country, fontsize=8)

# Setting plot labels and title
plt.title('Scatter Plot: Total Cases vs Total Deaths')
plt.xlabel('Total Cases')
plt.ylabel('Total Deaths')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#composition bar chart of total cases, deaths and recovered
top_10_countries = df.nlargest(10, 'Total Cases')

plt.figure(figsize=(12, 8))
sns.barplot(x='Country', y='Total Cases', data=top_10_countries, color='skyblue', label='Total Cases')
sns.barplot(x='Country', y='Total Recovered', data=top_10_countries, color='lightgreen', label='Total Recovered')
sns.barplot(x='Country', y='Total Deaths', data=top_10_countries, color='red', label='Total Deaths')

plt.xlabel('Countries')
plt.ylabel('Count')
plt.title('COVID-19 Data for Top 10 Countries')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
#Top 20 Countries in view of Total Cases per 1 million
df1=df.sort_values('Tot Cases/1M pop',ascending=False)
fig = px.bar(df1.head(20), x='Country', y='Tot Cases/1M pop', color='Country')
fig.update_layout(template='gridon')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total Cases per 1 million",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="b04f2fdc-8807-40e2-a7ce-43a0f82ff87c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b04f2fdc-8807-40e2-a7ce-43a0f82ff87c")) {                    Plotly.newPlot(                        "b04f2fdc-8807-40e2-a7ce-43a0f82ff87c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Brunei","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Brunei","offsetgroup":"Brunei","orientation":"v","showlegend":true,"textposition":"auto","x":["Brunei"],"xaxis":"x","y":[769596.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"San Marino","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"San Marino","offsetgroup":"San Marino","orientation":"v","showlegend":true,"textposition":"auto","x":["San Marino"],"xaxis":"x","y":[768226.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Faeroe Islands","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Faeroe Islands","offsetgroup":"Faeroe Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Faeroe Islands"],"xaxis":"x","y":[703959.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[673523.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria"],"xaxis":"x","y":[670727.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Slovenia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Slovenia","offsetgroup":"Slovenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Slovenia"],"xaxis":"x","y":[652733.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Niue","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Niue","offsetgroup":"Niue","orientation":"v","showlegend":true,"textposition":"auto","x":["Niue"],"xaxis":"x","y":[650432.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Andorra"],"xaxis":"x","y":[619844.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"Martinique","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Martinique","offsetgroup":"Martinique","orientation":"v","showlegend":true,"textposition":"auto","x":["Martinique"],"xaxis":"x","y":[615777.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tot Cases/1M pop=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[612013.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hov ...

# %% [markdown]
# ## Population analysis

# %%
#population vs total cases chart
plt.figure(figsize=(12, 6))

x=np.arange(10)
width = 0.2
  
# plot data in grouped manner of bar type 

plt.bar(x, df[:10]['Population'], width, color='green') 
plt.bar(x-0.2, df[:10]['Total Cases'], width, color='red') 
#plt.bar(x+0.2,top_10_countries['Total Deaths'], width, color='green') 
plt.xticks(x, df[:10]['Country']) 
plt.xlabel("Countries") 
plt.ylabel("Numbers") 
plt.legend(["Population","Total Cases"]) 
plt.show()

# %%
#pie chart of average population and average cases in the world
avg_population = df['Total Recovered'].mean()
avg_cases = df['Total Deaths'].mean()

sizes = [avg_population, avg_cases]
labels = ['Average population', 'Average number of cases']

plt.figure(figsize=(5,5))
plt.pie(sizes, labels=labels,  startangle=190, colors=sns.color_palette('pastel'))
plt.axis('equal')
plt.title('Distribution of Average population and Average number of cases')
plt.show()

# %%
#dataframe sorted on the basis of population
df_pop=df.sort_values('Population',ascending=False)
df_pop
# Out:
#               Country   Total Cases  New Cases  Total Deaths  New Deaths  \
# 230             China    503302.000      0.000      5272.000       0.000
# 1               India  45028429.000    161.000    533475.000       2.000
# 0                 USA 111367209.000      0.000   1199031.000       0.000
# 19          Indonesia   6828605.000      0.000    162033.000       0.000
# 52           Pakistan   1581936.000      0.000     30664.000       0.000
# ..                ...           ...        ...           ...         ...
# 224              Niue      1055.000      0.000         0.000       0.000
# 226           Tokelau        80.000      0.000         0.000       0.000
# 227      Vatican City        29.000      0.000         0.000       0.000
# 225  Diamond Princess       712.000      0.000        13.000       0.000
# 229        MS Zaandam         9.000      0.000         2.000       0.000
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 230       379053.000          0.000    118977.000              0.000
# 1              0.000          0.000         0.000              0.000
# 0      109053249.000          0.000   1114929.000           1771.000
# 19       6647104.000          0.000     19468.000              0.000
# 52       1538689.000          0.000     12583.000              0.000
# ..               ...            ...           ...                ...
# 224         1053.000          0.000         2.000              0.000
# 226            0.000          0.000        80.000              0.000
# 227           29.000          0.000         0.000              0.000
# 225          699.000          0.000         0.000              0.000
# 229            7.000          0.000         0.000              0.000
#
#      Tot Cases/1M pop  Deaths/1M pop    Total Tests  Tests/1M pop  \
# 230           347.000          4.000  160000000.000    110461.000
# 1           32012.000        379.000  935879495.000    665334.000
# 0          332633.000       3581.000 1186742917.000   3544577.000
# 19          24463.000        580.000  114158919.000    408975.000
# 52           6893.000        134.000   30589153.000    133292.000
# ..                ...            ...            ...           ...
# 224        650432.000          0.000          0.000         0.000
# 226         58055.000          0.000          0.000         0.000
# 227         36295.000          0.000          0.000         0.000
# 225             0.000          0.000          0.000         0.000
# 229             0.000          0.000          0.000         0.000
#
#         Population
# 230 1448471400.000
# 1   1406631776.000
# 0    334805269.000
# 19   279134505.000
# 52   229488994.000
# ..             ...
# 224       1622.000
# 226       1378.000
# 227        799.000
# 225          0.000
# 229          0.000
#
# [231 rows x 14 columns]

# %%
#Top 10 countries with total number of cases vs population
fig = go.Figure()
fig.add_trace(go.Bar(x=df[:10].Country, y=df['Population'][:10],marker_color='green',name='Population'))
fig.add_trace(go.Bar(x=df[:10].Country, y=df['Total Cases'][:10],marker_color='red',name='Total Cases'))
fig.update_layout(template='simple_white')
fig.update_layout(title="Comparison between population and Total number of Cases",
                 xaxis_title = "Country Name", yaxis_title= "Population")
fig.show()
# Out:
# <div>                            <div id="3c66d901-16b7-419a-96af-89389997f7b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c66d901-16b7-419a-96af-89389997f7b4")) {                    Plotly.newPlot(                        "3c66d901-16b7-419a-96af-89389997f7b4",                        [{"marker":{"color":"green"},"name":"Population","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[334805269.0,1406631776.0,65584518.0,83883596.0,215353593.0,51329899.0,125584838.0,60262770.0,68497907.0,145805947.0],"type":"bar"},{"marker":{"color":"red"},"name":"Total Cases","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[111367209.0,45028429.0,40138560.0,38819284.0,38407327.0,34571873.0,33803572.0,26716804.0,24898914.0,23957146.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"], ...

# %% [markdown]
# ## Country centered analysis

# %%
#Top 10 populated countries vs total cases
fig = go.Figure()
fig.add_trace(go.Bar(x=df_pop[:10].Country, y=df_pop['Population'][:10],marker_color='green',name='Population'))
fig.add_trace(go.Bar(x=df_pop[:10].Country, y=df_pop['Total Cases'][:10],marker_color='red',name='Total Cases'))
fig.update_layout(template='simple_white')
fig.update_layout(title="Comparison between population and Total number of Cases",
                 xaxis_title = "Country Name", yaxis_title= "Population")
fig.show()
# Out:
# <div>                            <div id="0e8d407e-56a0-4613-a84c-23349a4da66e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e8d407e-56a0-4613-a84c-23349a4da66e")) {                    Plotly.newPlot(                        "0e8d407e-56a0-4613-a84c-23349a4da66e",                        [{"marker":{"color":"green"},"name":"Population","x":["China","India","USA","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico"],"y":[1448471400.0,1406631776.0,334805269.0,279134505.0,229488994.0,216746934.0,215353593.0,167885689.0,145805947.0,131562772.0],"type":"bar"},{"marker":{"color":"red"},"name":"Total Cases","x":["China","India","USA","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico"],"y":[503302.0,45028429.0,111367209.0,6828605.0,1581936.0,267188.0,38407327.0,2047373.0,23957146.0,7702809.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.888888 ...

# %%
#Top 20 Countries in view of Total Cases
fig = px.bar(df.head(20), x='Country', y='Total Cases', color='Country')
fig.update_layout(template='presentation')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total Cases",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="be8a328b-60ee-4317-8c55-1f676eca6b15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be8a328b-60ee-4317-8c55-1f676eca6b15")) {                    Plotly.newPlot(                        "be8a328b-60ee-4317-8c55-1f676eca6b15",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":["USA"],"xaxis":"x","y":[111367209.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[45028429.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[40138560.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[38819284.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[38407327.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[34571873.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Japan","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[33803572.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[26716804.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"UK","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"v","showlegend":true,"textposition":"auto","x":["UK"],"xaxis":"x","y":[24898914.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[23957146.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Cases=%{y}<extra></extra>","legendgroup":"Turkey","marker":{"color":"#636efa","pattern":{"shape":""}}, ...

# %%
#Top 20 Countries in view of Total Deaths
df_deaths=df.sort_values(by=['Total Deaths'],ascending=False)
fig = px.bar(df_deaths.head(20), x='Country', y='Total Deaths',hover_data=['Total Deaths'], color='Country')
fig.update_layout(template='presentation')
fig.update_layout(title="Top 20 Countries in view of Total Deaths",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")

fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="6e785563-5ff5-4957-9392-60ae4f907537" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e785563-5ff5-4957-9392-60ae4f907537")) {                    Plotly.newPlot(                        "6e785563-5ff5-4957-9392-60ae4f907537",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":["USA"],"xaxis":"x","y":[1199031.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[709765.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[533475.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[402264.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"v","showlegend":true,"textposition":"auto","x":["Mexico"],"xaxis":"x","y":[334958.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"UK","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"v","showlegend":true,"textposition":"auto","x":["UK"],"xaxis":"x","y":[232112.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Peru","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Peru","offsetgroup":"Peru","orientation":"v","showlegend":true,"textposition":"auto","x":["Peru"],"xaxis":"x","y":[222161.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[196257.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[182439.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[167642.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Deaths=%{y}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Indonesia" ...

# %%
#Top 20 Countries in view of Total Recovered
df_recovered=df.sort_values('Total Recovered',ascending=False)
fig = px.bar(df_recovered.head(20), x='Country', y='Total Recovered', color='Country')
fig.update_layout(template='presentation')
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total Recovered",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="53805633-1295-471a-8174-d4ecb06120fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53805633-1295-471a-8174-d4ecb06120fd")) {                    Plotly.newPlot(                        "53805633-1295-471a-8174-d4ecb06120fd",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":["USA"],"xaxis":"x","y":[109053249.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[39970918.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[38240600.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[36249161.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[34535939.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[26347863.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"UK","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"v","showlegend":true,"textposition":"auto","x":["UK"],"xaxis":"x","y":[24655170.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[23370779.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Spain","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":["Spain"],"xaxis":"x","y":[13762417.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Vietnam","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Vietnam","offsetgroup":"Vietnam","orientation":"v","showlegend":true,"textposition":"auto","x":["Vietnam"],"xaxis":"x","y":[10640971.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Recovered=%{y}<extra></extra>","legendgroup":"Taiwan", ...

# %%
df_test=df.sort_values('Total Tests',ascending=False)
fig = px.bar(df_test.head(20), x='Country', y='Total Tests', color='Country')
fig.update_layout(template='presentation')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total Tests",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="eb7f50f3-2128-4332-8c6e-5bb15ac6ccce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb7f50f3-2128-4332-8c6e-5bb15ac6ccce")) {                    Plotly.newPlot(                        "eb7f50f3-2128-4332-8c6e-5bb15ac6ccce",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":["USA"],"xaxis":"x","y":[1186742917.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[935879495.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"UK","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"v","showlegend":true,"textposition":"auto","x":["UK"],"xaxis":"x","y":[522526476.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"Spain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":["Spain"],"xaxis":"x","y":[471036328.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Italy"],"xaxis":"x","y":[280238086.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[273400000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["France"],"xaxis":"x","y":[271490188.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria"],"xaxis":"x","y":[211273524.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"UAE","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"UAE","offsetgroup":"UAE","orientation":"v","showlegend":true,"textposition":"auto","x":["UAE"],"xaxis":"x","y":[200732262.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"Turkey","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Turkey","offsetgroup":"Turkey","orientation":"v","showlegend":true,"textposition":"auto","x":["Turkey"],"xaxis":"x","y":[162743369.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total Tests=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Chi ...

# %% [markdown]
# ## Testing efforts

# %%
df1=df.sort_values('Deaths/1M pop',ascending=False)
fig = px.bar(df1.head(20), x='Country', y='Deaths/1M pop', color='Country')
fig.update_layout(template='presentation')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total deaths per 1 million",
                 xaxis_title= "Country Name",
                 yaxis_title= "Deaths/1M pop")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="9d55eee3-edde-4ae8-aa4e-450bd462aba2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d55eee3-edde-4ae8-aa4e-450bd462aba2")) {                    Plotly.newPlot(                        "9d55eee3-edde-4ae8-aa4e-450bd462aba2",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Peru","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Peru","offsetgroup":"Peru","orientation":"v","showlegend":true,"textposition":"auto","x":["Peru"],"xaxis":"x","y":[6595.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Bulgaria","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bulgaria","offsetgroup":"Bulgaria","orientation":"v","showlegend":true,"textposition":"auto","x":["Bulgaria"],"xaxis":"x","y":[5660.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Hungary","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Hungary","offsetgroup":"Hungary","orientation":"v","showlegend":true,"textposition":"auto","x":["Hungary"],"xaxis":"x","y":[5105.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Bosnia and Herzegovina","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bosnia and Herzegovina","offsetgroup":"Bosnia and Herzegovina","orientation":"v","showlegend":true,"textposition":"auto","x":["Bosnia and Herzegovina"],"xaxis":"x","y":[5042.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"North Macedonia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North Macedonia","offsetgroup":"North Macedonia","orientation":"v","showlegend":true,"textposition":"auto","x":["North Macedonia"],"xaxis":"x","y":[4791.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Croatia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Croatia","offsetgroup":"Croatia","orientation":"v","showlegend":true,"textposition":"auto","x":["Croatia"],"xaxis":"x","y":[4604.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Montenegro","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Montenegro","offsetgroup":"Montenegro","orientation":"v","showlegend":true,"textposition":"auto","x":["Montenegro"],"xaxis":"x","y":[4531.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Georgia","offsetgroup":"Georgia","orientation":"v","showlegend":true,"textposition":"auto","x":["Georgia"],"xaxis":"x","y":[4317.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Czechia","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Czechia","offsetgroup":"Czechia","orientation":"v","showlegend":true,"textposition":"auto","x":["Czechia"],"xaxis":"x","y":[4052.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Deaths/1M pop=%{y}<extra></extra>","legendgroup":"Slovakia","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Slovakia","offsetgroup":"Slovakia","orientation":"v","showlegend":true,"textposition":"auto","x":["Slovakia"],"xaxis":"x","y":[3886.0],"yaxis":"y","type":"bar"},{"alignmentgroup":" ...

# %%
#Top 10 countries with total number of cases vs total number of tests
fig = go.Figure()
fig.add_trace(go.Bar(x=df[:10].Country, y=df['Total Tests'][:10],marker_color='green',name='Total Tests'))
fig.add_trace(go.Bar(x=df[:10].Country, y=df['Total Cases'][:10],marker_color='red',name='Total Cases'))
fig.update_layout(template='simple_white')
fig.update_layout(title="Comparison between Total Tests and Total number of Cases")
fig.show()
# Out:
# <div>                            <div id="214a163b-8b99-4d3c-b9b4-a14b580f4182" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("214a163b-8b99-4d3c-b9b4-a14b580f4182")) {                    Plotly.newPlot(                        "214a163b-8b99-4d3c-b9b4-a14b580f4182",                        [{"marker":{"color":"green"},"name":"Total Tests","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[1186742917.0,935879495.0,271490188.0,122332384.0,63776166.0,15804065.0,100414883.0,280238086.0,522526476.0,273400000.0],"type":"bar"},{"marker":{"color":"red"},"name":"Total Cases","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[111367209.0,45028429.0,40138560.0,38819284.0,38407327.0,34571873.0,33803572.0,26716804.0,24898914.0,23957146.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2 ...

# %%
#Top 20 Countries in view of Total tests per 1 million
df1=df.sort_values('Tests/1M pop',ascending=False)
fig = px.bar(df1.head(20), x='Country', y='Tests/1M pop', color='Country')
fig.update_layout(template='plotly')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total tests per 1 million",
                 xaxis_title= "Country Name",
                 yaxis_title= "total tests")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="c45d75f6-99d5-4179-94fb-f181a4d39356" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c45d75f6-99d5-4179-94fb-f181a4d39356")) {                    Plotly.newPlot(                        "c45d75f6-99d5-4179-94fb-f181a4d39356",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria"],"xaxis":"x","y":[23302116.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Denmark","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Denmark","offsetgroup":"Denmark","orientation":"v","showlegend":true,"textposition":"auto","x":["Denmark"],"xaxis":"x","y":[22165247.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"UAE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"UAE","offsetgroup":"UAE","orientation":"v","showlegend":true,"textposition":"auto","x":["UAE"],"xaxis":"x","y":[19910389.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Bermuda"],"xaxis":"x","y":[16622128.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Gibraltar","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Gibraltar","offsetgroup":"Gibraltar","orientation":"v","showlegend":true,"textposition":"auto","x":["Gibraltar"],"xaxis":"x","y":[15852213.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Faeroe Islands","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Faeroe Islands","offsetgroup":"Faeroe Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Faeroe Islands"],"xaxis":"x","y":[15802409.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Turks and Caicos","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Turks and Caicos","offsetgroup":"Turks and Caicos","orientation":"v","showlegend":true,"textposition":"auto","x":["Turks and Caicos"],"xaxis":"x","y":[15517224.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Spain","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":["Spain"],"xaxis":"x","y":[10082298.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Hong Kong","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Hong Kong","offsetgroup":"Hong Kong","orientation":"v","showlegend":true,"textposition":"auto","x":["Hong Kong"],"xaxis":"x","y":[10011143.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Tests/1M pop=%{y}<extra></extra>","legendgroup":"Greece","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Greece","offsetgroup":"Greece","orientation":"v","showlegend":true,"textposition":"auto","x":["Greece"],"xaxis":"x","y":[9909078.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplat ...

# %%
#Bar Chart between cases and tests per 1 million
fig = go.Figure(data=[
    go.Bar(x=df[:10].Country, y=df['Tot Cases/1M pop'][:10], marker_color='#fcbd22', name='Tot Cases/1M pop'),
    go.Bar(x=df[:10].Country, y=df['Tests/1M pop'][:10], marker_color='#3f98b4', name='Tests/1M pop')
])
fig.update_layout(barmode='group')
fig.update_layout(template='simple_white')
fig.update_layout(title="A comparitive Bar Chart between cases and tests per 1 million",
                 xaxis_title= "Country Name",
                 yaxis_title= "Number")
fig.show()
# Out:
# <div>                            <div id="e7d17ea9-2c41-440c-a0f6-37f5cb346f81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7d17ea9-2c41-440c-a0f6-37f5cb346f81")) {                    Plotly.newPlot(                        "e7d17ea9-2c41-440c-a0f6-37f5cb346f81",                        [{"marker":{"color":"#fcbd22"},"name":"Tot Cases/1M pop","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[332633.0,32012.0,612013.0,462776.0,178345.0,673523.0,269169.0,443338.0,363499.0,164308.0],"type":"bar"},{"marker":{"color":"#3f98b4"},"name":"Tests/1M pop","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[3544577.0,665334.0,4139547.0,1458359.0,296146.0,307892.0,799578.0,4650269.0,7628357.0,1875095.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"hist ...

# %%
#creating new dataframe with additional columns that represent different attribute rates
df_new=df.copy()
df_new['Test positivity rate']=df['Total Cases']/df['Total Tests']
df_new=df_new.sort_values('Test positivity rate',ascending=False)



df_new['Cases per population']=df['Total Cases']/df['Population']
df_new=df_new.sort_values('Cases per population',ascending=False)

df_new['Death rate']=df['Total Deaths']/df['Total Cases']
df_new=df_new.sort_values('Death rate',ascending=False)

df_new['Test rate']=df['Total Tests']/df['Population']
df_new=df_new.sort_values('Test rate',ascending=False)

df_new['Recovery rate']=df['Total Recovered']/df['Total Cases']
df_new=df_new.sort_values('Recovery rate',ascending=False)


df_new.replace([np.inf], 0, inplace=True)

df_new
# Out:
#               Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 227      Vatican City       29.000      0.000         0.000       0.000
# 222  Falkland Islands     1930.000      0.000         0.000       0.000
# 31               DPRK  4772813.000      0.000        74.000       0.000
# 5            S. Korea 34571873.000      0.000     35934.000       0.000
# 188  Marshall Islands    16138.000      0.000        17.000       0.000
# ..                ...          ...        ...           ...         ...
# 82             Kuwait   667026.000      0.000      2570.000       0.000
# 206      Sierra Leone     7779.000      0.000       126.000       0.000
# 132            Malawi    89168.000      0.000      2686.000       0.000
# 10             Turkey 17232066.000      0.000    102174.000       0.000
# 217          Anguilla     3904.000      0.000        12.000       0.000
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 227           29.000          0.000         0.000              0.000
# 222         1930.000          0.000         0.000              0.000
# 31       4772739.000          0.000         0.000              0.000
# 5       34535939.000          0.000         0.000              0.000
# 188        16121.000          0.000         0.000              0.000
# ..               ...            ...           ...                ...
# 82             0.000          0.000         0.000              0.000
# 206            0.000          0.000         0.000              0.000
# 132            0.000          0.000         0.000              0.000
# 10             0.000          0.000         0.000              0.000
# 217            0.000          0.000         0.000              0.000
#
#      Tot Cases/1M pop  Deaths/1M pop   Total Tests  Tests/1M pop   Population  \
# 227         36295.000          0.000         0.000         0.000      799.000
# 222        545352.000          0.000      8632.000   2439107.000     3539.000
# 31         183636.000          3.000         0.000         0.000 25990679.000
# 5          673523.000        700.000  15804065.000    307892.000 51329899.000
# 188        268711.000        283.000         0.000         0.000    60057.000
# ..                ...            ...           ...           ...          ...
# 82         152278.000        587.000   8455743.000   1930391.000  4380326.000
# 206           937.000         15.000    259958.000     31296.000  8306436.000
# 132          4418.000        133.000    624784.000     30959.000 20180839.000
# 10         201399.000       1194.000 162743369.000   1902052.000 85561976.000
# 217        256336.000        788.000     51382.000   3373736.000    15230.000
#
#      Test positivity rate  Cases per population  Death rate  Test rate  \
# 227                 0.000                 0.036       0.000      0.000
# 222                 0.224                 0.545       0.000      2.439
# 31                  0.000                 0.184       0.000      0.000
# 5                   2.188                 0.674       0.001      0.308
# 188                 0.000                 0.269       0.001      0.000
# ..                    ...                   ...         ...        ...
# 82                  0.079                 0.152       0.004      1.930
# 206                 0.030                 0.001       0.016      0.031
# 132                 0.143                 0.004       0.030      0.031
# 10                  0.106                 0.201       0.006      1.902
# 217                 0.076                 0.256       0.003      3.374
#
#      Recovery rate
# 227          1.000
# 222          1.000
# 31           1.000
# 5            0.999
# 188          0.999
# ..             ...
# 82           0.000
# 206          0.000
# 132          0.000
# 10           0.000
# 217          0.000
#
# [231 rows x 19 columns]

# %%
#Test positivity rate graph of top 20 countries
df_sort=df_new.sort_values('Test positivity rate',ascending=False)
fig = px.bar(df_sort.head(20), x='Country', y='Test positivity rate', color='Country')
fig.update_layout(template='plotly')
fig.update_layout(title="Top 20 Countries in view of Test positivity rate",
                 xaxis_title= "Country Name",
                 yaxis_title= "Test positivity rate")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="3297da04-2edb-4f1e-aea9-e688c1d9acfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3297da04-2edb-4f1e-aea9-e688c1d9acfc")) {                    Plotly.newPlot(                        "3297da04-2edb-4f1e-aea9-e688c1d9acfc",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Macao","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Macao","offsetgroup":"Macao","orientation":"v","showlegend":true,"textposition":"auto","x":["Macao"],"xaxis":"x","y":[2.892484076433121],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[2.1875304233436146],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Algeria"],"xaxis":"x","y":[1.1777364045722203],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"New Caledonia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"New Caledonia","offsetgroup":"New Caledonia","orientation":"v","showlegend":true,"textposition":"auto","x":["New Caledonia"],"xaxis":"x","y":[0.8090214623499454],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[0.6022206947968619],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Antigua and Barbuda"],"xaxis":"x","y":[0.4817734511401513],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Vanuatu","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Vanuatu","offsetgroup":"Vanuatu","orientation":"v","showlegend":true,"textposition":"auto","x":["Vanuatu"],"xaxis":"x","y":[0.4812219730941704],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Brunei","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Brunei","offsetgroup":"Brunei","orientation":"v","showlegend":true,"textposition":"auto","x":["Brunei"],"xaxis":"x","y":[0.47758378565139376],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Slovenia","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Slovenia","offsetgroup":"Slovenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Slovenia"],"xaxis":"x","y":[0.47631475355032005],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test positivity rate=%{y}<extra></extra>","legendgroup":"Bolivia","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Bolivia","offsetgroup":"Bolivia"," ...

# %%
#Top 20 Countries in view of Cases per population
df_sort=df_new.sort_values('Cases per population',ascending=False)
fig = px.bar(df_sort.head(20), x='Country', y='Cases per population', color='Country')
fig.update_layout(template='plotly')
fig.update_layout(title="Top 20 Countries in view of Cases per population",
                 xaxis_title= "Country Name",
                 yaxis_title= "Cases per population")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="97bc6e08-069c-47a8-85f5-d6ecdbba0578" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97bc6e08-069c-47a8-85f5-d6ecdbba0578")) {                    Plotly.newPlot(                        "97bc6e08-069c-47a8-85f5-d6ecdbba0578",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Brunei","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Brunei","offsetgroup":"Brunei","orientation":"v","showlegend":true,"textposition":"auto","x":["Brunei"],"xaxis":"x","y":[0.7695961888597785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"San Marino","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"San Marino","offsetgroup":"San Marino","orientation":"v","showlegend":true,"textposition":"auto","x":["San Marino"],"xaxis":"x","y":[0.7682264925920493],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Faeroe Islands","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Faeroe Islands","offsetgroup":"Faeroe Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Faeroe Islands"],"xaxis":"x","y":[0.7039587268701887],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[0.6735231058997408],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria"],"xaxis":"x","y":[0.6707269781431192],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Slovenia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Slovenia","offsetgroup":"Slovenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Slovenia"],"xaxis":"x","y":[0.6527333046523781],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Niue","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Niue","offsetgroup":"Niue","orientation":"v","showlegend":true,"textposition":"auto","x":["Niue"],"xaxis":"x","y":[0.6504315659679408],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Andorra"],"xaxis":"x","y":[0.6198443127686767],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"Martinique","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Martinique","offsetgroup":"Martinique","orientation":"v","showlegend":true,"textposition":"auto","x":["Martinique"],"xaxis":"x","y":[0.6157765439590256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Cases per population=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showle ...

# %%
#Top 20 Countries in view of death rate
df_sort=df_new.sort_values('Death rate',ascending=False)
fig = px.bar(df_sort.head(20), x='Country', y='Death rate', color='Country')
fig.update_layout(template='seaborn')
# Alternative way for doing background dark
#fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of death rate",
                 yaxis_title= "Death rate")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="56d6b42f-993a-4c11-b220-195f01b94f72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56d6b42f-993a-4c11-b220-195f01b94f72")) {                    Plotly.newPlot(                        "56d6b42f-993a-4c11-b220-195f01b94f72",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"MS Zaandam","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MS Zaandam","offsetgroup":"MS Zaandam","orientation":"v","showlegend":true,"textposition":"auto","x":["MS Zaandam"],"xaxis":"x","y":[0.2222222222222222],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Yemen","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yemen","offsetgroup":"Yemen","orientation":"v","showlegend":true,"textposition":"auto","x":["Yemen"],"xaxis":"x","y":[0.18074508162411052],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Western Sahara","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Western Sahara","offsetgroup":"Western Sahara","orientation":"v","showlegend":true,"textposition":"auto","x":["Western Sahara"],"xaxis":"x","y":[0.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Sudan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Sudan","offsetgroup":"Sudan","orientation":"v","showlegend":true,"textposition":"auto","x":["Sudan"],"xaxis":"x","y":[0.07885237447845858],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Syria","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Syria","offsetgroup":"Syria","orientation":"v","showlegend":true,"textposition":"auto","x":["Syria"],"xaxis":"x","y":[0.054811838664426855],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Somalia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Somalia","offsetgroup":"Somalia","orientation":"v","showlegend":true,"textposition":"auto","x":["Somalia"],"xaxis":"x","y":[0.04979146850076827],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Peru","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Peru","offsetgroup":"Peru","orientation":"v","showlegend":true,"textposition":"auto","x":["Peru"],"xaxis":"x","y":[0.04858455688988505],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Egypt","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Egypt","offsetgroup":"Egypt","orientation":"v","showlegend":true,"textposition":"auto","x":["Egypt"],"xaxis":"x","y":[0.04769748635235251],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"v","showlegend":true,"textposition":"auto","x":["Mexico"],"xaxis":"x","y":[0.04348517534317676],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Death rate=%{y}<extra></extra>","legendgroup":"Bosnia and Herzegovina","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Bosnia and Herzegovina","offsetgroup":"Bosnia and Herzegovina","orientation":"v","showlegend":true,"textposition":"auto","x":["Bosnia and Herzegovina"],"xaxis":"x","y":[0.040593212989233456],"yaxis": ...

# %%
#Top 20 Countries in view of Test rate
df_sort=df_new.sort_values('Test rate',ascending=False)
fig = px.bar(df_sort.head(20), x='Country', y='Test rate', color='Country')
fig.update_layout(template='ggplot2')
fig.update_layout(title="Top 20 Countries in view of Test rate",
                 xaxis_title= "Country Name",
                 yaxis_title= "Test rate")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="48f0e354-4776-49d4-9524-9ab4c95e2b3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48f0e354-4776-49d4-9524-9ab4c95e2b3c")) {                    Plotly.newPlot(                        "48f0e354-4776-49d4-9524-9ab4c95e2b3c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Austria","offsetgroup":"Austria","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria"],"xaxis":"x","y":[23.302115541359544],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Denmark","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Denmark","offsetgroup":"Denmark","orientation":"v","showlegend":true,"textposition":"auto","x":["Denmark"],"xaxis":"x","y":[22.165246831592388],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"UAE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"UAE","offsetgroup":"UAE","orientation":"v","showlegend":true,"textposition":"auto","x":["UAE"],"xaxis":"x","y":[19.91038908288562],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Bermuda"],"xaxis":"x","y":[16.62212822292901],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Gibraltar","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Gibraltar","offsetgroup":"Gibraltar","orientation":"v","showlegend":true,"textposition":"auto","x":["Gibraltar"],"xaxis":"x","y":[15.852213387135059],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Faeroe Islands","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Faeroe Islands","offsetgroup":"Faeroe Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Faeroe Islands"],"xaxis":"x","y":[15.802408953344301],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Turks and Caicos","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Turks and Caicos","offsetgroup":"Turks and Caicos","orientation":"v","showlegend":true,"textposition":"auto","x":["Turks and Caicos"],"xaxis":"x","y":[15.517224025565536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Spain","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":["Spain"],"xaxis":"x","y":[10.082298343578314],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Hong Kong","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Hong Kong","offsetgroup":"Hong Kong","orientation":"v","showlegend":true,"textposition":"auto","x":["Hong Kong"],"xaxis":"x","y":[10.011143038957306],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Test rate=%{y}<extra></extra>","legendgroup":"Greece","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Greece","offsetgroup":"Greece","orientation":"v","showlegend":true,"textposition":"auto","x":["Greece"],"xaxis":"x","y":[9.909078413828071],"yaxis":"y","typ ...

# %%
#Top 20 Countries in view of recovery rate
df_sort=df_new.sort_values('Recovery rate',ascending=False)
fig = px.bar(df_sort.head(20), x='Country', y='Recovery rate', color='Country')
fig.update_layout(template='plotly')
fig.update_layout(title="Top 20 Countries in view of recovery rate",
                 xaxis_title= "Country Name",
                 yaxis_title= "Recovery rate")
fig.update_xaxes(tickangle=270)
fig.show()
# Out:
# <div>                            <div id="0a68489a-cf53-4ae1-bb74-c586a0d3cf49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a68489a-cf53-4ae1-bb74-c586a0d3cf49")) {                    Plotly.newPlot(                        "0a68489a-cf53-4ae1-bb74-c586a0d3cf49",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Vatican City","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Vatican City","offsetgroup":"Vatican City","orientation":"v","showlegend":true,"textposition":"auto","x":["Vatican City"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Falkland Islands","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Falkland Islands","offsetgroup":"Falkland Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Falkland Islands"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"DPRK","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"DPRK","offsetgroup":"DPRK","orientation":"v","showlegend":true,"textposition":"auto","x":["DPRK"],"xaxis":"x","y":[0.9999844955165853],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"S. Korea","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"S. Korea","offsetgroup":"S. Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["S. Korea"],"xaxis":"x","y":[0.9989606001387312],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Marshall Islands","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Marshall Islands","offsetgroup":"Marshall Islands","orientation":"v","showlegend":true,"textposition":"auto","x":["Marshall Islands"],"xaxis":"x","y":[0.9989465856983517],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Singapore","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Singapore","offsetgroup":"Singapore","orientation":"v","showlegend":true,"textposition":"auto","x":["Singapore"],"xaxis":"x","y":[0.9989282614815445],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Qatar"],"xaxis":"x","y":[0.9983732537257737],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Palau","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Palau","offsetgroup":"Palau","orientation":"v","showlegend":true,"textposition":"auto","x":["Palau"],"xaxis":"x","y":[0.9982481286829112],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Taiwan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Taiwan","offsetgroup":"Taiwan","orientation":"v","showlegend":true,"textposition":"auto","x":["Taiwan"],"xaxis":"x","y":[0.9981443189650602],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Recovery rate=%{y}<extra></extra>","legendgroup":"Niue","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Niue","offsetgroup":"Niue","orientation":"v","showlegend":true,"textposition":"auto","x":["Niue"],"xaxis":"x","y":[0.9981042654028 ...

# %% [markdown]
# ## Region/ country comparison

# %%
import plotly.graph_objs as go
import plotly.io as pio

# You may need to download the world choropleth map
pio.templates.default = "plotly"
world_map = go.Figure(go.Choropleth(
    locations = df['Country'],
    z = df['Total Cases'],
    locationmode = 'country names',
    colorscale = 'Blues',
    colorbar_title = 'Total',
))

world_map.update_layout(
    title_text = 'Total COVID-19 Cases by Country',
    geo=dict(
        showcoastlines=True,
        showland=True,
        showframe=False,
        projection_type='equirectangular'
    )
)
world_map.show()
# Out:
# <div>                            <div id="321bd0f1-a988-40b9-ad3c-d23ccdae9344" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("321bd0f1-a988-40b9-ad3c-d23ccdae9344")) {                    Plotly.newPlot(                        "321bd0f1-a988-40b9-ad3c-d23ccdae9344",                        [{"colorbar":{"title":{"text":"Total"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"locationmode":"country names","locations":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","Indonesia","Poland","Colombia","Greece","Austria","Portugal","Ukraine","Chile","Malaysia","Canada","Belgium","Israel","DPRK","Thailand","Czechia","Peru","Switzerland","Philippines","South Africa","Romania","Denmark","Singapore","Hong Kong","Sweden","Serbia","New Zealand","Iraq","Hungary","Bangladesh","Slovakia","Georgia","Jordan","Ireland","Pakistan","Finland","Norway","Kazakhstan","Lithuania","Slovenia","Bulgaria","Croatia","Guatemala","Morocco","Lebanon","Costa Rica","Bolivia","Tunisia","Cuba","Ecuador","UAE","Panama","Uruguay","Mongolia","Nepal","Belarus","Latvia","Saudi Arabia","Paraguay","Azerbaijan","Bahrain","Cyprus","Dominican Republic","Sri Lanka","Kuwait","Myanmar","Moldova","Estonia","Palestine","Venezuela","Egypt","Qatar","Libya","Ethiopia","R\u00e9union","Honduras","Armenia","Bosnia and Herzegovina","Oman","Luxembourg","North Macedonia","Zambia","Kenya","Brunei","Albania","Botswana","Montenegro","Algeria","Nigeria","Zimbabwe","Uzbekistan","Mozambique","Afghanistan","Martinique","Laos","Iceland","Kyrgyzstan","Guadeloupe","El Salvador","Trinidad and Tobago","Maldives","Namibia","Uganda","Ghana","Jamaica","Cambodia","Rwanda","Cameroon","Malta","Barbados","Angola","Channel Islands","DRC","French Guiana","Malawi","Senegal","Ivory Coast","Suriname","New Caledonia","French Polynesia","Eswatini","Guyana","Belize","Fiji","Madagascar","Cabo Verde","Sudan","Mauritania","Bhutan","Syria","Burundi","Seychelles","Gabon","Andorra","Papua New Guinea","Cura\u00e7ao","Aruba","Tanzania","Mauritius","Mayotte","Togo","Guinea","Bahamas","Isle of Man","Lesotho","Faeroe Islands","Haiti","Mali","Cayman Islands","Saint Lucia","Benin","Somalia","Micronesia","San Marino","Solomon Islands","Congo","Timor-Leste","Macao","Burkina Faso","Liechtenstein","Gibraltar","Grenada","Bermuda","South Sudan","Nicaragua","Tajikistan","Equatorial Guinea","Monaco","Samoa","Tonga","Marshall Islands","Dominica","Djibouti","CAR","Gambia","Saint Martin","Vanuatu","Greenland","Yemen","Caribbean Netherlands","Sint Maarten","Eritrea","Niger","St. Vincent Grenadines","Guinea-Bissau","Comoros","Antigua and Barbuda","Liberia","Sierra Leone","Chad","British Virgin Islands","Cook Islands","Sao Tome and Principe","Turks and Caicos","Saint Kitts and Nevis","Palau","St. Barth","Nauru","Kiribati","Anguilla","Wallis and Futuna","Saint Pierre Miquelon","Tuvalu","Saint Helena","Falkland Islands","Montserrat","Niue","Diamond Princess","Tokelau","Vatican City","Western Sahara","MS Zaandam","China"],"z":[111367209.0,45028429.0,40138560.0,38819284.0,38407327.0,34571873.0,33803572.0,26716804.0,24898914.0,23957146.0,17232066.0,13914811.0,11812730.0,11624114.0,10241523.0,10094643.0,8634340.0,7702809.0,7626527.0,6828605.0,6659256.0,6390825.0,6101379.0,6081287.0,5642217.0,5557995.0,5356303.0,5274786.0,4929750.0,4858488.0,4841772.0,4772813.0,4766751.0,4758292.0,4572667.0,4451386.0,4140383.0,4076463.0,3524982.0,3183756.0,3001665.0,2928551.0,2753119.0,2614044.0,2592549.0,2465545.0 ...

# %%
#Total COVID-19 Tests conducted by Country

pio.templates.default = "plotly"
world_map = go.Figure(go.Choropleth(
    locations = df['Country'],
    z = df['Tests/1M pop'],
    locationmode = 'country names',
    colorscale = 'Greens',
    colorbar_title = 'Total',
))

world_map.update_layout(
    title_text = 'Total COVID-19 Tests conducted by Country',
    geo=dict(
        showcoastlines=True,
        showland=True,
        showframe=False,
        projection_type='equirectangular'
    )
)
world_map.show()
# Out:
# <div>                            <div id="d096dccf-8298-4de4-bf0e-64cc0ebbb7bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d096dccf-8298-4de4-bf0e-64cc0ebbb7bf")) {                    Plotly.newPlot(                        "d096dccf-8298-4de4-bf0e-64cc0ebbb7bf",                        [{"colorbar":{"title":{"text":"Total"}},"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]],"locationmode":"country names","locations":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","Indonesia","Poland","Colombia","Greece","Austria","Portugal","Ukraine","Chile","Malaysia","Canada","Belgium","Israel","DPRK","Thailand","Czechia","Peru","Switzerland","Philippines","South Africa","Romania","Denmark","Singapore","Hong Kong","Sweden","Serbia","New Zealand","Iraq","Hungary","Bangladesh","Slovakia","Georgia","Jordan","Ireland","Pakistan","Finland","Norway","Kazakhstan","Lithuania","Slovenia","Bulgaria","Croatia","Guatemala","Morocco","Lebanon","Costa Rica","Bolivia","Tunisia","Cuba","Ecuador","UAE","Panama","Uruguay","Mongolia","Nepal","Belarus","Latvia","Saudi Arabia","Paraguay","Azerbaijan","Bahrain","Cyprus","Dominican Republic","Sri Lanka","Kuwait","Myanmar","Moldova","Estonia","Palestine","Venezuela","Egypt","Qatar","Libya","Ethiopia","R\u00e9union","Honduras","Armenia","Bosnia and Herzegovina","Oman","Luxembourg","North Macedonia","Zambia","Kenya","Brunei","Albania","Botswana","Montenegro","Algeria","Nigeria","Zimbabwe","Uzbekistan","Mozambique","Afghanistan","Martinique","Laos","Iceland","Kyrgyzstan","Guadeloupe","El Salvador","Trinidad and Tobago","Maldives","Namibia","Uganda","Ghana","Jamaica","Cambodia","Rwanda","Cameroon","Malta","Barbados","Angola","Channel Islands","DRC","French Guiana","Malawi","Senegal","Ivory Coast","Suriname","New Caledonia","French Polynesia","Eswatini","Guyana","Belize","Fiji","Madagascar","Cabo Verde","Sudan","Mauritania","Bhutan","Syria","Burundi","Seychelles","Gabon","Andorra","Papua New Guinea","Cura\u00e7ao","Aruba","Tanzania","Mauritius","Mayotte","Togo","Guinea","Bahamas","Isle of Man","Lesotho","Faeroe Islands","Haiti","Mali","Cayman Islands","Saint Lucia","Benin","Somalia","Micronesia","San Marino","Solomon Islands","Congo","Timor-Leste","Macao","Burkina Faso","Liechtenstein","Gibraltar","Grenada","Bermuda","South Sudan","Nicaragua","Tajikistan","Equatorial Guinea","Monaco","Samoa","Tonga","Marshall Islands","Dominica","Djibouti","CAR","Gambia","Saint Martin","Vanuatu","Greenland","Yemen","Caribbean Netherlands","Sint Maarten","Eritrea","Niger","St. Vincent Grenadines","Guinea-Bissau","Comoros","Antigua and Barbuda","Liberia","Sierra Leone","Chad","British Virgin Islands","Cook Islands","Sao Tome and Principe","Turks and Caicos","Saint Kitts and Nevis","Palau","St. Barth","Nauru","Kiribati","Anguilla","Wallis and Futuna","Saint Pierre Miquelon","Tuvalu","Saint Helena","Falkland Islands","Montserrat","Niue","Diamond Princess","Tokelau","Vatican City","Western Sahara","MS Zaandam","China"],"z":[3544577.0,665334.0,4139547.0,1458359.0,296146.0,307892.0,799578.0,4650269.0,7628357.0,1875095.0,1902052.0,10082298.0,3142326.0,867342.0,1286903.0,776264.0,1509718.0,152124.0,666338.0,408975.0,1040263.0,717327.0,9909078.0,23302116.0,4549993.0,754855.0,2617225.0,2066869.0,1734189.0,3209915.0,4436346.0,0.0,246488.0,5381551.0,1158115.0,2716487.0,320888.0,441027.0,1503632.0,22165247.0,4165302.0,10011143.0,1908301.0,1550919.0,1586011.0,463523.0,1186160.0,90862.0,1364199.0,4263340. ...

# %%
# Total COVID-19 deaths by Country
pio.templates.default = "plotly"
world_map = go.Figure(go.Choropleth(
    locations = df['Country'],
    z = df['Total Deaths'],
    locationmode = 'country names',
    colorscale = 'Reds',
    colorbar_title = 'Total',
))

world_map.update_layout(
    title_text = 'Total COVID-19 deaths by Country',
    geo=dict(
        showcoastlines=True,
        showland=True,
        showframe=False,
        projection_type='equirectangular'
    )
)
world_map.show()
# Out:
# <div>                            <div id="8be4d3a5-9780-42b6-a55d-00ebe6f66953" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8be4d3a5-9780-42b6-a55d-00ebe6f66953")) {                    Plotly.newPlot(                        "8be4d3a5-9780-42b6-a55d-00ebe6f66953",                        [{"colorbar":{"title":{"text":"Total"}},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"locationmode":"country names","locations":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","Indonesia","Poland","Colombia","Greece","Austria","Portugal","Ukraine","Chile","Malaysia","Canada","Belgium","Israel","DPRK","Thailand","Czechia","Peru","Switzerland","Philippines","South Africa","Romania","Denmark","Singapore","Hong Kong","Sweden","Serbia","New Zealand","Iraq","Hungary","Bangladesh","Slovakia","Georgia","Jordan","Ireland","Pakistan","Finland","Norway","Kazakhstan","Lithuania","Slovenia","Bulgaria","Croatia","Guatemala","Morocco","Lebanon","Costa Rica","Bolivia","Tunisia","Cuba","Ecuador","UAE","Panama","Uruguay","Mongolia","Nepal","Belarus","Latvia","Saudi Arabia","Paraguay","Azerbaijan","Bahrain","Cyprus","Dominican Republic","Sri Lanka","Kuwait","Myanmar","Moldova","Estonia","Palestine","Venezuela","Egypt","Qatar","Libya","Ethiopia","R\u00e9union","Honduras","Armenia","Bosnia and Herzegovina","Oman","Luxembourg","North Macedonia","Zambia","Kenya","Brunei","Albania","Botswana","Montenegro","Algeria","Nigeria","Zimbabwe","Uzbekistan","Mozambique","Afghanistan","Martinique","Laos","Iceland","Kyrgyzstan","Guadeloupe","El Salvador","Trinidad and Tobago","Maldives","Namibia","Uganda","Ghana","Jamaica","Cambodia","Rwanda","Cameroon","Malta","Barbados","Angola","Channel Islands","DRC","French Guiana","Malawi","Senegal","Ivory Coast","Suriname","New Caledonia","French Polynesia","Eswatini","Guyana","Belize","Fiji","Madagascar","Cabo Verde","Sudan","Mauritania","Bhutan","Syria","Burundi","Seychelles","Gabon","Andorra","Papua New Guinea","Cura\u00e7ao","Aruba","Tanzania","Mauritius","Mayotte","Togo","Guinea","Bahamas","Isle of Man","Lesotho","Faeroe Islands","Haiti","Mali","Cayman Islands","Saint Lucia","Benin","Somalia","Micronesia","San Marino","Solomon Islands","Congo","Timor-Leste","Macao","Burkina Faso","Liechtenstein","Gibraltar","Grenada","Bermuda","South Sudan","Nicaragua","Tajikistan","Equatorial Guinea","Monaco","Samoa","Tonga","Marshall Islands","Dominica","Djibouti","CAR","Gambia","Saint Martin","Vanuatu","Greenland","Yemen","Caribbean Netherlands","Sint Maarten","Eritrea","Niger","St. Vincent Grenadines","Guinea-Bissau","Comoros","Antigua and Barbuda","Liberia","Sierra Leone","Chad","British Virgin Islands","Cook Islands","Sao Tome and Principe","Turks and Caicos","Saint Kitts and Nevis","Palau","St. Barth","Nauru","Kiribati","Anguilla","Wallis and Futuna","Saint Pierre Miquelon","Tuvalu","Saint Helena","Falkland Islands","Montserrat","Niue","Diamond Princess","Tokelau","Vatican City","Western Sahara","MS Zaandam","China"],"z":[1199031.0,533475.0,167642.0,182439.0,709765.0,35934.0,74694.0,196257.0,232112.0,402264.0,102174.0,121760.0,24228.0,43206.0,19005.0,130733.0,22992.0,334958.0,146799.0,162033.0,120553.0,143146.0,37869.0,22542.0,28093.0,112418.0,64497.0,37347.0,58348.0,34376.0,12707.0,74.0,34564.0,43503.0,222161.0,14452.0,66864.0,102595.0,68860.0,8814.0,1933.0,14542.0,27293.0,18057.0,5533.0,25375.0,49039.0,29482.0,21219.0,17132.0,14122.0,9480.0,30664.0,11939.0,6636.0,13848.0,9895.0,7100.0,3873 ...

# %% [markdown]
# ## Correlation and prediction

# %%
# Assign the columns
columns_of_interest = ['Total Cases', 'Total Deaths', 'Total Recovered', 'Total Tests']

# Calculate the correlation matrix
correlation_matrix = df[columns_of_interest].corr()

# Display the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.xticks(rotation=30, ha='right')
plt.show()

# %%
# Assign the columns
columns_of_interest = ['Population','New Cases','New Deaths','New Recovered','Serious, Critical','Tot Cases/1M pop','Deaths/1M pop','Tests/1M pop']

# Calculate the correlation matrix
correlation_matrix = df[columns_of_interest].corr()

# Display the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.xticks(rotation=30, ha='right')
plt.show()

# %%
#correlation
columns_of_interest = ['Test positivity rate', 'Cases per population', 'Recovery rate', 'Test rate','Death rate']

# Calculate the correlation matrix
correlation_matrix = df_new[columns_of_interest].corr()

# Display the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.xticks(rotation=30, ha='right')
plt.show()

# %%
#correlation
heatmap = df
heatmap = heatmap.set_index('Country')
heatmap = heatmap.sort_values('Population',ascending=False)[0:9]
heatmap = heatmap.drop(['Population','New Cases','New Deaths','New Recovered','Serious, Critical','Tot Cases/1M pop','Deaths/1M pop','Tests/1M pop'],axis=1)
heatmap = heatmap * .000001
plt.xlabel('Category')
plt.ylabel('Country')
plt.title('Global Heatmap [Scaled by 1e^6, descending by pop.]')
sns.heatmap(heatmap, cmap='YlGnBu',annot=True,linewidths=2)
# Out:
# <AxesSubplot:title={'center':'Global Heatmap [Scaled by 1e^6, descending by pop.]'}, ylabel='Country'>
